# %%
from pymongo.mongo_client import MongoClient
uri = "mongodb+srv://snshrivas:Snshrivas@cluster0.u46c4.mongodb.net/?retryWrites=true&w=majority"
# Create a new client and connect to the server
client = MongoClient(uri)

# %%
database=client["youtubecomunity"]

# %%
collection=database["session"]

# %%
data={

    "coursename":"genai",
    "instrutorname":"sunny",
    "modeofsession":"english"
}

# %%
data
# Out:
# {'coursename': 'genai', 'instrutorname': 'sunny', 'modeofsession': 'english'}

# %%
collection.insert_one(data)
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 collection.insert_one(data)
#
# File c:\Users\Oliver\anaconda4\envs\genai\lib\site-packages\pymongo\collection.py:669, in Collection.insert_one(self, document, bypass_document_validation, session, comment)
#     665     document["_id"] = ObjectId()  # type: ignore[index]
#     667 write_concern = self._write_concern_for(session)
#     668 return InsertOneResult(
# --> 669     self._insert_one(
#     670         document,
#     671         ordered=True,
#     672         write_concern=write_concern,
#     673         op_id=None,
#     674         bypass_doc_val=bypass_document_validation,
#     675         session=session,
#     676         comment=comment,
#     677     ),
#     678     write_concern.acknowledged,
#     679 )
#
# File c:\Users\Oliver\anaconda4\envs\genai\lib\site-packages\pymongo\collection.py:609, in Collection._insert_one(self, doc, ordered, write_concern, op_id, bypass_doc_val, session, comment)
#     597     result = conn.command(
#     598         self.__database.name,
#     599         command,
#    (...)
#     604         retryable_write=retryable_write,
#     605     )
#     607     _check_write_command_response(result)
# --> 609 self.__database.client._retryable_write(acknowledged, _insert_command, session)
#     611 if not isinstance(doc, RawBSONDocument):
#     612     return doc.get("_id")
#
# File c:\Users\Oliver\anaconda4\envs\genai\lib\site-packages\pymongo\mongo_client.py:1523, in MongoClient._retryable_write(self, retryable, func, session, bulk)
#    1509 """Execute an operation with consecutive retries if possible
#    1510
#    1511 Returns func()'s return value on success. On error retries the same
#    (...)
#    1520   - `bulk`: bulk abstraction to execute operations in bulk, defaults to None
#    1521 """
#    1522 with self._tmp_session(session) as s:
# -> 1523     return self._retry_with_session(retryable, func, s, bulk)
#
# File c:\Users\Oliver\anaconda4\envs\genai\lib\site-packages\pymongo\mongo_client.py:1421, in MongoClient._retry_with_session(self, retryable, func, session, bulk)
#    1416 # Ensure that the options supports retry_writes and there is a valid session not in
#    1417 # transaction, otherwise, we will not support retry behavior for this txn.
#    1418 retryable = bool(
#    1419     retryable and self.options.retry_writes and session and not session.in_transaction
#    1420 )
# -> 1421 return self._retry_internal(
#    1422     func=func,
#    1423     session=session,
#    1424     bulk=bulk,
#    1425     retryable=retryable,
#    1426 )
#
# File c:\Users\Oliver\anaconda4\envs\genai\lib\site-packages\pymongo\_csot.py:107, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     105         with _TimeoutContext(timeout):
#     106             return func(self, *args, **kwargs)
# --> 107 return func(self, *args, **kwargs)
#
# File c:\Users\Oliver\anaconda4\envs\genai\lib\site-packages\pymongo\mongo_client.py:1453, in MongoClient._retry_internal(self, func, session, bulk, is_read, address, read_pref, retryable)
#    1428 @_csot.apply
#    1429 def _retry_internal(
#    1430     self,
#    (...)
#    1437     retryable: bool = False,
#    1438 ) -> T:
#    1439     """Internal retryable helper for all client transactions.
#    1440
#    1441     :Parameters:
#    (...)
#    1451       Output of the calling func()
#    1452     """
# -> 1453     return _ClientConnectionRetryable(
#    1454         mongo_client=self,
#    1455         func=func,
#    1456         bulk=bulk,
#    1457         is_read=is_read,
#    1458         session=session,
#    1459         read_pref=read_pref,
#    1460         address=address,
#    1461         retryable=retryable,
#    1462     ).run()
#
# File c:\Users\Oliver\anaconda4\envs\genai\lib\site-packages\pymongo\mongo_client.py:2315, in _ClientConnectionRetryable.run(self)
#    2313 self._check_last_error(check_csot=True)
#    2314 try:
# -> 2315     return self._read() if self._is_read else self._write()
#    2316 except ServerSelectionTimeoutError:
#    2317     # The application may think the write was never attempted
#    2318     # if we raise ServerSelectionTimeoutError on the retry
#    2319     # attempt. Raise the original exception instead.
#    2320     self._check_last_error()
#
# File c:\Users\Oliver\anaconda4\envs\genai\lib\site-packages\pymongo\mongo_client.py:2416, in _ClientConnectionRetryable._write(self)
#    2412 self._server = self._get_server()
#    2413 supports_session = (
#    2414     self._session is not None and self._server.description.retryable_writes_supported
#    2415 )
# -> 2416 with self._client._checkout(self._server, self._session) as conn:
#    2417     max_wire_version = conn.max_wire_version
#    2418     if self._retryable and not supports_session:
#    2419         # A retry is not possible because this server does
#    2420         # not support sessions raise the last error.
#
# File c:\Users\Oliver\anaconda4\envs\genai\lib\contextlib.py:113, in _GeneratorContextManager.__enter__(self)
#     111 del self.args, self.kwds, self.func
#     112 try:
# --> 113     return next(self.gen)
#     114 except StopIteration:
#     115     raise RuntimeError("generator didn't yield") from None
#
# File c:\Users\Oliver\anaconda4\envs\genai\lib\site-packages\pymongo\mongo_client.py:1252, in MongoClient._checkout(self, server, session)
#    1250     yield session._pinned_connection
#    1251     return
# -> 1252 with server.checkout(handler=err_handler) as conn:
#    1253     # Pin this session to the selected server or connection.
#    1254     if (
#    1255         in_txn
#    1256         and session
#    (...)
#    1261         )
#    1262     ):
#    1263         session._pin(server, conn)
#
# File c:\Users\Oliver\anaconda4\envs\genai\lib\contextlib.py:113, in _GeneratorContextManager.__enter__(self)
#     111 del self.args, self.kwds, self.func
#     112 try:
# --> 113     return next(self.gen)
#     114 except StopIteration:
#     115     raise RuntimeError("generator didn't yield") from None
#
# File c:\Users\Oliver\anaconda4\envs\genai\lib\site-packages\pymongo\pool.py:1637, in Pool.checkout(self, handler)
#    1634     assert listeners is not None
#    1635     listeners.publish_connection_check_out_started(self.address)
# -> 1637 conn = self._get_conn(handler=handler)
#    1639 if self.enabled_for_cmap:
#    1640     assert listeners is not None
#
# File c:\Users\Oliver\anaconda4\envs\genai\lib\site-packages\pymongo\pool.py:1756, in Pool._get_conn(self, handler)
#    1754 else:  # We need to create a new connection
#    1755     try:
# -> 1756         conn = self.connect(handler=handler)
#    1757     finally:
#    1758         with self._max_connecting_cond:
#
# File c:\Users\Oliver\anaconda4\envs\genai\lib\site-packages\pymongo\pool.py:1607, in Pool.connect(self, handler)
#    1604     if handler:
#    1605         handler.contribute_socket(conn, completed_handshake=False)
# -> 1607     conn.authenticate()
#    1608 except BaseException:
#    1609     conn.close_conn(ConnectionClosedReason.ERROR)
#
# File c:\Users\Oliver\anaconda4\envs\genai\lib\site-packages\pymongo\pool.py:1078, in Connection.authenticate(self, reauthenticate)
#    1076 creds = self.opts._credentials
#    1077 if creds:
# -> 1078     auth.authenticate(creds, self, reauthenticate=reauthenticate)
#    1079 self.ready = True
#    1080 if self.enabled_for_cmap:
#
# File c:\Users\Oliver\anaconda4\envs\genai\lib\site-packages\pymongo\auth.py:625, in authenticate(credentials, conn, reauthenticate)
#     623     _authenticate_oidc(credentials, conn, reauthenticate)
#     624 else:
# --> 625     auth_func(credentials, conn)
#
# File c:\Users\Oliver\anaconda4\envs\genai\lib\site-packages\pymongo\auth.py:530, in _authenticate_default(credentials, conn)
#     528         return _authenticate_scram(credentials, conn, "SCRAM-SHA-256")
#     529     else:
# --> 530         return _authenticate_scram(credentials, conn, "SCRAM-SHA-1")
#     531 else:
#     532     return _authenticate_scram(credentials, conn, "SCRAM-SHA-1")
#
# File c:\Users\Oliver\anaconda4\envs\genai\lib\site-packages\pymongo\auth.py:298, in _authenticate_scram(credentials, conn, mechanism)
#     289 server_sig = standard_b64encode(_hmac(server_key, auth_msg, digestmod).digest())
#     291 cmd = SON(
#     292     [
#     293         ("saslContinue", 1),
#    (...)
#     296     ]
#     297 )
# --> 298 res = conn.command(source, cmd)
#     300 parsed = _parse_scram_response(res["payload"])
#     301 if not hmac.compare_digest(parsed[b"v"], server_sig):
#
# File c:\Users\Oliver\anaconda4\envs\genai\lib\site-packages\pymongo\helpers.py:322, in _handle_reauth.<locals>.inner(*args, **kwargs)
#     319 from pymongo.pool import Connection
#     321 try:
# --> 322     return func(*args, **kwargs)
#     323 except OperationFailure as exc:
#     324     if no_reauth:
#
# File c:\Users\Oliver\anaconda4\envs\genai\lib\site-packages\pymongo\pool.py:968, in Connection.command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     966     self._raise_if_not_writable(unacknowledged)
#     967 try:
# --> 968     return command(
#     969         self,
#     970         dbname,
#     971         spec,
#     972         self.is_mongos,
#     973         read_preference,
#     974         codec_options,
#     975         session,
#     976         client,
#     977         check,
#     978         allowable_errors,
#     979         self.address,
#     980         listeners,
#     981         self.max_bson_size,
#     982         read_concern,
#     983         parse_write_concern_error=parse_write_concern_error,
#     984         collation=collation,
#     985         compression_ctx=self.compression_context,
#     986         use_op_msg=self.op_msg_enabled,
#     987         unacknowledged=unacknowledged,
#     988         user_fields=user_fields,
#     989         exhaust_allowed=exhaust_allowed,
#     990         write_concern=write_concern,
#     991     )
#     992 except (OperationFailure, NotPrimaryError):
#     993     raise
#
# File c:\Users\Oliver\anaconda4\envs\genai\lib\site-packages\pymongo\network.py:192, in command(conn, dbname, spec, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed, write_concern)
#     190             client._process_response(response_doc, session)
#     191         if check:
# --> 192             helpers._check_command_response(
#     193                 response_doc,
#     194                 conn.max_wire_version,
#     195                 allowable_errors,
#     196                 parse_write_concern_error=parse_write_concern_error,
#     197             )
#     198 except Exception as exc:
#     199     if publish:
#
# File c:\Users\Oliver\anaconda4\envs\genai\lib\site-packages\pymongo\helpers.py:230, in _check_command_response(response, max_wire_version, allowable_errors, parse_write_concern_error)
#     227 elif code == 43:
#     228     raise CursorNotFound(errmsg, code, response, max_wire_version)
# --> 230 raise OperationFailure(errmsg, code, response, max_wire_version)
#
# OperationFailure: bad auth : authentication failed, full error: {'ok': 0, 'errmsg': 'bad auth : authentication failed', 'code': 8000, 'codeName': 'AtlasError'}

# %%
all_record=collection.find()

# %%
for record in all_record:
    print(record)
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 for record in all_record:
#       2     print(record)
#
# File c:\Users\Oliver\anaconda4\envs\genai\lib\site-packages\pymongo\cursor.py:1264, in Cursor.next(self)
#    1262 if self.__empty:
#    1263     raise StopIteration
# -> 1264 if len(self.__data) or self._refresh():
#    1265     return self.__data.popleft()
#    1266 else:
#
# File c:\Users\Oliver\anaconda4\envs\genai\lib\site-packages\pymongo\cursor.py:1181, in Cursor._refresh(self)
#    1159         raise InvalidOperation(
#    1160             "Passing a 'hint' is required when using the min/max query"
#    1161             " option to ensure the query utilizes the correct index"
#    1162         )
#    1163     q = self._query_class(
#    1164         self.__query_flags,
#    1165         self.__collection.database.name,
#    (...)
#    1179         self.__exhaust,
#    1180     )
# -> 1181     self.__send_message(q)
#    1182 elif self.__id:  # Get More
#    1183     if self.__limit:
#
# File c:\Users\Oliver\anaconda4\envs\genai\lib\site-packages\pymongo\cursor.py:1060, in Cursor.__send_message(self, operation)
#    1057     raise InvalidOperation("exhaust cursors do not support auto encryption")
#    1059 try:
# -> 1060     response = client._run_operation(
#    1061         operation, self._unpack_response, address=self.__address
#    1062     )
#    1063 except OperationFailure as exc:
#    1064     if exc.code in _CURSOR_CLOSED_ERRORS or self.__exhaust:
#    1065         # Don't send killCursors because the cursor is already closed.
#
# File c:\Users\Oliver\anaconda4\envs\genai\lib\site-packages\pymongo\_csot.py:107, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     105         with _TimeoutContext(timeout):
#     106             return func(self, *args, **kwargs)
# --> 107 return func(self, *args, **kwargs)
#
# File c:\Users\Oliver\anaconda4\envs\genai\lib\site-packages\pymongo\mongo_client.py:1394, in MongoClient._run_operation(self, operation, unpack_res, address)
#    1389     operation.reset()  # Reset op in case of retry.
#    1390     return server.run_operation(
#    1391         conn, operation, read_preference, self._event_listeners, unpack_res
#    1392     )
# -> 1394 return self._retryable_read(
#    1395     _cmd,
#    1396     operation.read_preference,
#    1397     operation.session,
#    1398     address=address,
#    1399     retryable=isinstance(operation, message._Query),
#    1400 )
#
# File c:\Users\Oliver\anaconda4\envs\genai\lib\site-packages\pymongo\mongo_client.py:1492, in MongoClient._retryable_read(self, func, read_pref, session, address, retryable)
#    1487 # Ensure that the client supports retrying on reads and there is no session in
#    1488 # transaction, otherwise, we will not support retry behavior for this call.
#    1489 retryable = bool(
#    1490     retryable and self.options.retry_reads and not (session and session.in_transaction)
#    1491 )
# -> 1492 return self._retry_internal(
#    1493     func,
#    1494     session,
#    1495     None,
#    1496     is_read=True,
#    1497     address=address,
#    1498     read_pref=read_pref,
#    1499     retryable=retryable,
#    1500 )
#
# File c:\Users\Oliver\anaconda4\envs\genai\lib\site-packages\pymongo\_csot.py:107, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     105         with _TimeoutContext(timeout):
#     106             return func(self, *args, **kwargs)
# --> 107 return func(self, *args, **kwargs)
#
# File c:\Users\Oliver\anaconda4\envs\genai\lib\site-packages\pymongo\mongo_client.py:1453, in MongoClient._retry_internal(self, func, session, bulk, is_read, address, read_pref, retryable)
#    1428 @_csot.apply
#    1429 def _retry_internal(
#    1430     self,
#    (...)
#    1437     retryable: bool = False,
#    1438 ) -> T:
#    1439     """Internal retryable helper for all client transactions.
#    1440
#    1441     :Parameters:
#    (...)
#    1451       Output of the calling func()
#    1452     """
# -> 1453     return _ClientConnectionRetryable(
#    1454         mongo_client=self,
#    1455         func=func,
#    1456         bulk=bulk,
#    1457         is_read=is_read,
#    1458         session=session,
#    1459         read_pref=read_pref,
#    1460         address=address,
#    1461         retryable=retryable,
#    1462     ).run()
#
# File c:\Users\Oliver\anaconda4\envs\genai\lib\site-packages\pymongo\mongo_client.py:2315, in _ClientConnectionRetryable.run(self)
#    2313 self._check_last_error(check_csot=True)
#    2314 try:
# -> 2315     return self._read() if self._is_read else self._write()
#    2316 except ServerSelectionTimeoutError:
#    2317     # The application may think the write was never attempted
#    2318     # if we raise ServerSelectionTimeoutError on the retry
#    2319     # attempt. Raise the original exception instead.
#    2320     self._check_last_error()
#
# File c:\Users\Oliver\anaconda4\envs\genai\lib\site-packages\pymongo\mongo_client.py:2439, in _ClientConnectionRetryable._read(self)
#    2437 self._server = self._get_server()
#    2438 assert self._read_pref is not None, "Read Preference required on read calls"
# -> 2439 with self._client._conn_from_server(self._read_pref, self._server, self._session) as (
#    2440     conn,
#    2441     read_pref,
#    2442 ):
#    2443     if self._retrying and not self._retryable:
#    2444         self._check_last_error()
#
# File c:\Users\Oliver\anaconda4\envs\genai\lib\contextlib.py:113, in _GeneratorContextManager.__enter__(self)
#     111 del self.args, self.kwds, self.func
#     112 try:
# --> 113     return next(self.gen)
#     114 except StopIteration:
#     115     raise RuntimeError("generator didn't yield") from None
#
# File c:\Users\Oliver\anaconda4\envs\genai\lib\site-packages\pymongo\mongo_client.py:1330, in MongoClient._conn_from_server(self, read_preference, server, session)
#    1327 topology = self._get_topology()
#    1328 single = topology.description.topology_type == TOPOLOGY_TYPE.Single
# -> 1330 with self._checkout(server, session) as conn:
#    1331     if single:
#    1332         if conn.is_repl and not (session and session.in_transaction):
#    1333             # Use primary preferred to ensure any repl set member
#    1334             # can handle the request.
#
# File c:\Users\Oliver\anaconda4\envs\genai\lib\contextlib.py:113, in _GeneratorContextManager.__enter__(self)
#     111 del self.args, self.kwds, self.func
#     112 try:
# --> 113     return next(self.gen)
#     114 except StopIteration:
#     115     raise RuntimeError("generator didn't yield") from None
#
# File c:\Users\Oliver\anaconda4\envs\genai\lib\site-packages\pymongo\mongo_client.py:1252, in MongoClient._checkout(self, server, session)
#    1250     yield session._pinned_connection
#    1251     return
# -> 1252 with server.checkout(handler=err_handler) as conn:
#    1253     # Pin this session to the selected server or connection.
#    1254     if (
#    1255         in_txn
#    1256         and session
#    (...)
#    1261         )
#    1262     ):
#    1263         session._pin(server, conn)
#
# File c:\Users\Oliver\anaconda4\envs\genai\lib\contextlib.py:113, in _GeneratorContextManager.__enter__(self)
#     111 del self.args, self.kwds, self.func
#     112 try:
# --> 113     return next(self.gen)
#     114 except StopIteration:
#     115     raise RuntimeError("generator didn't yield") from None
#
# File c:\Users\Oliver\anaconda4\envs\genai\lib\site-packages\pymongo\pool.py:1637, in Pool.checkout(self, handler)
#    1634     assert listeners is not None
#    1635     listeners.publish_connection_check_out_started(self.address)
# -> 1637 conn = self._get_conn(handler=handler)
#    1639 if self.enabled_for_cmap:
#    1640     assert listeners is not None
#
# File c:\Users\Oliver\anaconda4\envs\genai\lib\site-packages\pymongo\pool.py:1756, in Pool._get_conn(self, handler)
#    1754 else:  # We need to create a new connection
#    1755     try:
# -> 1756         conn = self.connect(handler=handler)
#    1757     finally:
#    1758         with self._max_connecting_cond:
#
# File c:\Users\Oliver\anaconda4\envs\genai\lib\site-packages\pymongo\pool.py:1607, in Pool.connect(self, handler)
#    1604     if handler:
#    1605         handler.contribute_socket(conn, completed_handshake=False)
# -> 1607     conn.authenticate()
#    1608 except BaseException:
#    1609     conn.close_conn(ConnectionClosedReason.ERROR)
#
# File c:\Users\Oliver\anaconda4\envs\genai\lib\site-packages\pymongo\pool.py:1078, in Connection.authenticate(self, reauthenticate)
#    1076 creds = self.opts._credentials
#    1077 if creds:
# -> 1078     auth.authenticate(creds, self, reauthenticate=reauthenticate)
#    1079 self.ready = True
#    1080 if self.enabled_for_cmap:
#
# File c:\Users\Oliver\anaconda4\envs\genai\lib\site-packages\pymongo\auth.py:625, in authenticate(credentials, conn, reauthenticate)
#     623     _authenticate_oidc(credentials, conn, reauthenticate)
#     624 else:
# --> 625     auth_func(credentials, conn)
#
# File c:\Users\Oliver\anaconda4\envs\genai\lib\site-packages\pymongo\auth.py:530, in _authenticate_default(credentials, conn)
#     528         return _authenticate_scram(credentials, conn, "SCRAM-SHA-256")
#     529     else:
# --> 530         return _authenticate_scram(credentials, conn, "SCRAM-SHA-1")
#     531 else:
#     532     return _authenticate_scram(credentials, conn, "SCRAM-SHA-1")
#
# File c:\Users\Oliver\anaconda4\envs\genai\lib\site-packages\pymongo\auth.py:298, in _authenticate_scram(credentials, conn, mechanism)
#     289 server_sig = standard_b64encode(_hmac(server_key, auth_msg, digestmod).digest())
#     291 cmd = SON(
#     292     [
#     293         ("saslContinue", 1),
#    (...)
#     296     ]
#     297 )
# --> 298 res = conn.command(source, cmd)
#     300 parsed = _parse_scram_response(res["payload"])
#     301 if not hmac.compare_digest(parsed[b"v"], server_sig):
#
# File c:\Users\Oliver\anaconda4\envs\genai\lib\site-packages\pymongo\helpers.py:322, in _handle_reauth.<locals>.inner(*args, **kwargs)
#     319 from pymongo.pool import Connection
#     321 try:
# --> 322     return func(*args, **kwargs)
#     323 except OperationFailure as exc:
#     324     if no_reauth:
#
# File c:\Users\Oliver\anaconda4\envs\genai\lib\site-packages\pymongo\pool.py:968, in Connection.command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     966     self._raise_if_not_writable(unacknowledged)
#     967 try:
# --> 968     return command(
#     969         self,
#     970         dbname,
#     971         spec,
#     972         self.is_mongos,
#     973         read_preference,
#     974         codec_options,
#     975         session,
#     976         client,
#     977         check,
#     978         allowable_errors,
#     979         self.address,
#     980         listeners,
#     981         self.max_bson_size,
#     982         read_concern,
#     983         parse_write_concern_error=parse_write_concern_error,
#     984         collation=collation,
#     985         compression_ctx=self.compression_context,
#     986         use_op_msg=self.op_msg_enabled,
#     987         unacknowledged=unacknowledged,
#     988         user_fields=user_fields,
#     989         exhaust_allowed=exhaust_allowed,
#     990         write_concern=write_concern,
#     991     )
#     992 except (OperationFailure, NotPrimaryError):
#     993     raise
#
# File c:\Users\Oliver\anaconda4\envs\genai\lib\site-packages\pymongo\network.py:192, in command(conn, dbname, spec, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed, write_concern)
#     190             client._process_response(response_doc, session)
#     191         if check:
# --> 192             helpers._check_command_response(
#     193                 response_doc,
#     194                 conn.max_wire_version,
#     195                 allowable_errors,
#     196                 parse_write_concern_error=parse_write_concern_error,
#     197             )
#     198 except Exception as exc:
#     199     if publish:
#
# File c:\Users\Oliver\anaconda4\envs\genai\lib\site-packages\pymongo\helpers.py:230, in _check_command_response(response, max_wire_version, allowable_errors, parse_write_concern_error)
#     227 elif code == 43:
#     228     raise CursorNotFound(errmsg, code, response, max_wire_version)
# --> 230 raise OperationFailure(errmsg, code, response, max_wire_version)
#
# OperationFailure: bad auth : authentication failed, full error: {'ok': 0, 'errmsg': 'bad auth : authentication failed', 'code': 8000, 'codeName': 'AtlasError'}

# %%
collection.insert_many(
    [
        {

    "coursename":"genai",
    "instrutorname":"sunny",
    "modeofsession":"english"
},

{

    "coursename":"mlops",
    "instrutorname":"sunnysavita",
    "modeofsession":"english&hindi"
}
        
    ]
)
# Out:
# InsertManyResult([ObjectId('658e9fa55e020d6d30de40b8'), ObjectId('658e9fa55e020d6d30de40b9')], acknowledged=True)

# %%
class mongodb_operation:

    def __init__(self,client_url: str, database_name: str, collection_name: str=None):
        self.client_url=client_url
        self.database_name=database_name
        self.collection_name=collection_name

    def create_client(self):
        client=MongoClient(self.client_url)
        return client


    def create_database(self):
        client=self.create_client()
        database=client[self.database_name]
        return database
        
    def create_collection(self,collection=None):
        database=self.create_database()
        collection=database[collection]
        return collection

    def insert_record(self,record:dict,collection_name:str):
        if type(record)==list:
            for data in record:
                if type(data)!= dict:
                    raise TypeError("record must be in the dict")
            collection=self.create_collection(collection_name)
            collection.insert_many(record)
        elif type(record)==dict:
            collection=self.create_collection(collection_name)
            collection.insert_one(record)

    def bulk_insert(self,datafile:str,collection_name:str=None):
        self.path=datafile

        if self.path.endswith('.csv'):
            data=pd.read_csv(self.path,encoding='utf-8')

        elif self.path.endswith('.xlsx'):
            data=pd.read_excel(self.path,encoding='utf-8')
            
        datajson=json.loads(data.to_json(orient='record'))
        collection=self.create_collection()
        collection.insert_many(datajson)

# %%
#call the mongodb connection 
client_url =  "mongodb+srv://snshrivas:Snshrivas@cluster0.u46c4.mongodb.net/?retryWrites=true&w=majority"   # I have created a demo connection for you to understand. You can use your own.
database = "mynewdatabase"
collection_name = "myoldcolumn"

# %%
mongo=mongodb_operation(client_url,database,collection_name)

# %%
mongo.insert_record({"name":"sunny","designation":"data scientist","salary":"10k"},collection_name)

# %%
mongo.insert_record([{"name":"sunny","designation":"data scientist","salary":"10k"},
{"name":"sudhanshu","designation":"sr. data scientist","salary":"150k"},
{"name":"krish","designation":"lead data scientist","salary":"70k"}
],collection_name)
